# %% [markdown]
# **Purpose of the notebook: Format the date column to ensure proper datetime type and consistent format for further analysis.**

# %%
import os
os.chdir("C:/Users/zetru/OneDrive/Mémoire python/")
import numpy as np
import pandas as pd

# %%
df=pd.read_hdf('df_v1.h5','df_v1')
df
# Out:
#                id type  latitude  longitude code_postal  \
# 0         1000001    R    46.201      5.198       01000
# 1         1000001    R    46.201      5.198       01000
# 2         1000001    R    46.201      5.198       01000
# 3         1000001    R    46.201      5.198       01000
# 4         1000001    R    46.201      5.198       01000
# ...           ...  ...       ...        ...         ...
# 5032426  95870010    R    48.936      2.206       95870
# 5032427  95870010    R    48.936      2.206       95870
# 5032428  95870010    R    48.936      2.206       95870
# 5032429  95870010    R    48.936      2.206       95870
# 5032430  95870010    R    48.936      2.206       95870
#
#                          ville nom_carburant id_carburant  \
# 0        SAINT-DENIS-LèS-BOURG        Gazole            1
# 1        SAINT-DENIS-LèS-BOURG        Gazole            1
# 2        SAINT-DENIS-LèS-BOURG        Gazole            1
# ...

# %%
df['maj']=pd.to_datetime(df['maj']).dt.date
df['maj']=pd.to_datetime(df['maj'])

# %%
df['maj'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5027602 entries, 0 to 5032430
# Series name: maj
# Non-Null Count    Dtype
# --------------    -----
# 5027602 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 76.7 MB

# %%
df
# Out:
#                id type  latitude  longitude code_postal  \
# 0         1000001    R    46.201      5.198       01000
# 1         1000001    R    46.201      5.198       01000
# 2         1000001    R    46.201      5.198       01000
# 3         1000001    R    46.201      5.198       01000
# 4         1000001    R    46.201      5.198       01000
# ...           ...  ...       ...        ...         ...
# 5032426  95870010    R    48.936      2.206       95870
# 5032427  95870010    R    48.936      2.206       95870
# 5032428  95870010    R    48.936      2.206       95870
# 5032429  95870010    R    48.936      2.206       95870
# 5032430  95870010    R    48.936      2.206       95870
#
#                          ville nom_carburant id_carburant        maj  valeur  \
# 0        SAINT-DENIS-LèS-BOURG        Gazole            1 2022-01-03   1.572
# 1        SAINT-DENIS-LèS-BOURG        Gazole            1 2022-01-05   1.560
# ...

# %%
df_v2=df

# %%
df_v2.to_hdf('df_v2.h5',key='df_v2',mode='w')
