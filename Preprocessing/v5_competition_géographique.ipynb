# %% [markdown]
# **Purpose of the notebook: Calculate the numbers of stations in a 5km radius.**

# %%
import os
os.chdir("C:/Users/zetru/OneDrive/Mémoire python/")
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
df=pd.read_hdf('df_v4.h5','df_v4')
df
# Out:
#          cp        id nom_carburant id_carburant        maj    valeur  \
# 0        01   1000001        Gazole            1 2022-01-03  0.702500
# 1        01   1000001        Gazole            1 2022-01-05  0.692500
# 2        01   1000001        Gazole            1 2022-01-10  0.728333
# 3        01   1000001        Gazole            1 2022-01-17  0.739167
# 4        01   1000001        Gazole            1 2022-01-21  0.769167
# ...      ..       ...           ...          ...        ...       ...
# 4537444  95  95870010          SP98            6 2022-12-23  0.856233
# 4537445  95  95870010          SP98            6 2022-12-27  0.874567
# 4537446  95  95870010          SP98            6 2022-12-28  0.874567
# 4537447  95  95870010          SP98            6 2022-12-29  0.879567
# 4537448  95  95870010          SP98            6 2022-12-30  0.886233
#
#          litre_brut type  latitude  longitude                  ville
# 0          0.435626    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 1          0.447949    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 2          0.452874    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 3          0.484043    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 4          0.497616    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# ...             ...  ...       ...        ...                    ...
# 4537444    0.488413    R    48.936      2.206                 Bezons
# 4537445    0.487324    R    48.936      2.206                 Bezons
# 4537446    0.484175    R    48.936      2.206                 Bezons
# 4537447    0.477600    R    48.936      2.206                 Bezons
# 4537448    0.486593    R    48.936      2.206                 Bezons
#
# [4537449 rows x 11 columns]

# %%
from scipy.spatial import cKDTree

def degrees_to_radians(df):
    df.loc[:, 'latitude_rad'] = np.radians(df['latitude'])
    df.loc[:, 'longitude_rad'] = np.radians(df['longitude'])
    return df

def calculate_competition(unique_df, all_df, radius_km, station_type=['A', 'R']):
    radius_in_radians = radius_km / 6371.0088  # Rayon moyen de la terre en km
    
    # Filtrer les données uniques pour ne garder que les types spécifiés
    filtered_unique_df = unique_df[unique_df['type'].isin(station_type)]
    
    # Conversion des degrés en radians
    filtered_unique_df = degrees_to_radians(filtered_unique_df)
    coordinates = filtered_unique_df[['latitude_rad', 'longitude_rad']].values
    
    # Création de l'arbre KD à partir des coordonnées filtrées
    tree = cKDTree(coordinates)
    
    # Préparation des données uniques pour l'ensemble des stations
    unique_df = degrees_to_radians(unique_df)
    all_coordinates = unique_df[['latitude_rad', 'longitude_rad']].values
    
    # Recherche des voisins dans le rayon pour chaque point dans l'ensemble filtré
    counts = tree.query_ball_point(all_coordinates, r=radius_in_radians)
    
    # Calcul du nombre de stations du même type dans le rayon
    unique_df[f'stations_rayon_{radius_km}km'] = [len(count) - 1 for count in counts]

    all_df = all_df.merge(unique_df[['id', f'stations_rayon_{radius_km}km']], on='id', how='left')
    
    return all_df

unique_stations = df[['id', 'latitude', 'longitude', 'type']].drop_duplicates(subset='id')

df_stations = calculate_competition(unique_stations, df, 5)

# %%
df_stations
# Out:
#          cp        id nom_carburant id_carburant        maj    valeur  \
# 0        01   1000001        Gazole            1 2022-01-03  0.702500
# 1        01   1000001        Gazole            1 2022-01-05  0.692500
# 2        01   1000001        Gazole            1 2022-01-10  0.728333
# 3        01   1000001        Gazole            1 2022-01-17  0.739167
# 4        01   1000001        Gazole            1 2022-01-21  0.769167
# ...      ..       ...           ...          ...        ...       ...
# 4537444  95  95870010          SP98            6 2022-12-23  0.856233
# 4537445  95  95870010          SP98            6 2022-12-27  0.874567
# 4537446  95  95870010          SP98            6 2022-12-28  0.874567
# 4537447  95  95870010          SP98            6 2022-12-29  0.879567
# 4537448  95  95870010          SP98            6 2022-12-30  0.886233
#
#          litre_brut type  latitude  longitude                  ville  \
# 0          0.435626    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 1          0.447949    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 2          0.452874    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 3          0.484043    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 4          0.497616    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# ...             ...  ...       ...        ...                    ...
# 4537444    0.488413    R    48.936      2.206                 Bezons
# 4537445    0.487324    R    48.936      2.206                 Bezons
# 4537446    0.484175    R    48.936      2.206                 Bezons
# 4537447    0.477600    R    48.936      2.206                 Bezons
# 4537448    0.486593    R    48.936      2.206                 Bezons
#
#          stations_rayon_5km
# 0                         5
# 1                         5
# 2                         5
# 3                         5
# 4                         5
# ...                     ...
# 4537444                  15
# 4537445                  15
# 4537446                  15
# 4537447                  15
# 4537448                  15
#
# [4537449 rows x 12 columns]

# %%
df_stations['stations_rayon_5km'].quantile(0.75)
# Out:
# 9.0

# %%
labels = [1, 2, 3, 4]
df_stations['competition_geo'] = pd.qcut(df_stations['stations_rayon_5km'], q=4, labels=labels)

# %%
df_stations
# Out:
#          cp        id nom_carburant id_carburant        maj    valeur  \
# 0        01   1000001        Gazole            1 2022-01-03  0.702500
# 1        01   1000001        Gazole            1 2022-01-05  0.692500
# 2        01   1000001        Gazole            1 2022-01-10  0.728333
# 3        01   1000001        Gazole            1 2022-01-17  0.739167
# 4        01   1000001        Gazole            1 2022-01-21  0.769167
# ...      ..       ...           ...          ...        ...       ...
# 4537444  95  95870010          SP98            6 2022-12-23  0.856233
# 4537445  95  95870010          SP98            6 2022-12-27  0.874567
# 4537446  95  95870010          SP98            6 2022-12-28  0.874567
# 4537447  95  95870010          SP98            6 2022-12-29  0.879567
# 4537448  95  95870010          SP98            6 2022-12-30  0.886233
#
#          litre_brut type  latitude  longitude                  ville  \
# 0          0.435626    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 1          0.447949    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 2          0.452874    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 3          0.484043    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# 4          0.497616    R    46.201      5.198  SAINT-DENIS-LèS-BOURG
# ...             ...  ...       ...        ...                    ...
# 4537444    0.488413    R    48.936      2.206                 Bezons
# 4537445    0.487324    R    48.936      2.206                 Bezons
# 4537446    0.484175    R    48.936      2.206                 Bezons
# 4537447    0.477600    R    48.936      2.206                 Bezons
# 4537448    0.486593    R    48.936      2.206                 Bezons
#
#          stations_rayon_5km competition_geo
# 0                         5               3
# 1                         5               3
# 2                         5               3
# 3                         5               3
# 4                         5               3
# ...                     ...             ...
# 4537444                  15               4
# 4537445                  15               4
# 4537446                  15               4
# 4537447                  15               4
# 4537448                  15               4
#
# [4537449 rows x 13 columns]

# %%
df_stations['stations_rayon_5km'].idxmax()
# Out:
# 376568

# %%
df_a=df_stations[df_stations['type']=='A']
df_r=df_stations[df_stations['type']=='R']

# %%
df_a['stations_rayon_5km'].describe()
# Out:
# count    380270.000000
# mean          3.636705
# std           3.967912
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max          23.000000
# Name: stations_rayon_5km, dtype: float64

# %%
df_r['stations_rayon_5km'].describe()
# Out:
# count    4.157179e+06
# mean     6.420914e+00
# std      6.229963e+00
# min      0.000000e+00
# 25%      2.000000e+00
# 50%      4.000000e+00
# 75%      9.000000e+00
# max      3.600000e+01
# Name: stations_rayon_5km, dtype: float64

# %%
df_stations.sample(10)
# Out:
#          cp        id nom_carburant id_carburant        maj    valeur  \
# 3125462  69  69330006        Gazole            1 2022-12-08  0.999967
# 541296   14  14100007           E10            5 2022-04-29  0.903967
# 3661539  78  78230002           E85            3 2022-07-28  0.780867
# 1784459  40  40700004          SP95            2 2022-06-03  1.267300
# 2177595  51  51000001           E85            3 2022-01-22  0.464200
# 2384551  56  56860004           E85            3 2022-04-12  0.672533
# 4015320  85  85150001        Gazole            1 2022-01-04  0.638333
# 774670   21  21490003           E85            3 2022-05-07  0.697533
# 2031041  45  45520003           E10            5 2022-03-10  1.224800
# 2531846  59  59310001           E85            3 2022-10-13  0.880867
#
#          litre_brut type  latitude  longitude                 ville  \
# 3125462    0.452857    R    45.756     5.0670              PUSIGNAN
# 541296     0.646327    R    49.133     0.2245               LISIEUX
# 3661539    0.676483    R    48.881     2.0970               Le Pecq
# 1784459    0.737303    R    43.657    -0.5800              Hagetmau
# 2177595    0.497616    R    48.942     4.3890  CHâLONS-EN-CHAMPAGNE
# 2384551    0.606473    R    47.650    -2.7220                  SENE
# 4015320    0.442323    R    46.607    -1.6640           LES ACHARDS
# 774670     0.678488    A    47.422     5.1700               BROGNON
# 2031041    0.655740    A    47.980     1.8560                  GIDY
# 2531846    0.612185    R    50.470     3.2460               Orchies
#
#          stations_rayon_5km competition_geo
# 3125462                   2               1
# 541296                    3               2
# 3661539                  11               4
# 1784459                   2               1
# 2177595                   3               2
# 2384551                   6               3
# 4015320                   1               1
# 774670                    1               1
# 2031041                   3               2
# 2531846                   3               2

# %%
df_stations['competition_geo']=df_stations['competition_geo'].astype(object)

# %%
df_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4537449 entries, 0 to 4537448
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   cp                  object
#  1   id                  object
#  2   nom_carburant       object
#  3   id_carburant        object
#  4   maj                 datetime64[ns]
#  5   valeur              float64
#  6   litre_brut          float64
#  7   type                object
#  8   latitude            float64
#  9   longitude           float64
#  10  ville               object
#  11  stations_rayon_5km  int64
#  12  competition_geo     object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 450.0+ MB

# %%
df_stations.to_hdf('df_v5.h5',key='df_v5',mode='w')
# Out:
# C:\Users\zetru\AppData\Local\Temp\ipykernel_31972\3041895132.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block3_values] [items->Index(['cp', 'id', 'nom_carburant', 'id_carburant', 'type', 'ville',
#        'competition_geo'],
#       dtype='object')]
#
#   df_stations.to_hdf('df_v5.h5',key='df_v5',mode='w')
